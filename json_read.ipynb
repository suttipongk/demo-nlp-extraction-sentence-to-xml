# %%
# !pip install xmltodict

# %%
import xmltodict
import json
mydict={
    "process" : [
        {
            "sequence" : 1,         
            "sentence" : {
                "sentence":"The Vacation Request Process starts when an employee of the organization submits a vacation request.",
                "signal_word": "",
                "active_sentence" : {
                    "nsubj" : "The Vacation Request Process",
                    "verb" : "starts",
                    "dobj" : "a vacation request"
                }, 
                "passive_sentence" : { 
                    "nsubjpass":"",
                    "verb":"" 
                }
            },
            "process_name" : "The Vacation Request Process",
            "role_name" : "",
            "bpmn_event" : "START_EVENT",
            "bpmn_label" : "starts a vocation request",
        }, 
        { 
            "sequence" : 2,
            "check_sentence" : {
                "sentence":"The Vacation Request Process starts when an employee of the organization submits a vacation request.",
                "signal_word": "when",
                "active_sentence" : {
                    "nsubj" : "an employee",
                    "verb" : "submits",
                    "dobj" : "a vacation request"
                }, 
                "passive_sentence" : {
                    "nsubjpass" : "",
                    "verb" : ""
                }
            },
            "process_name" : "",
            "role_name" : "an employee",
            "bpmn_event" : "TASK_EVENT",
            "bpmn_label" : "submits a vocation request"
        }
    ]
}
print(xmltodict.unparse(mydict, pretty=True))
