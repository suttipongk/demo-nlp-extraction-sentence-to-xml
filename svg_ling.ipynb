# %%
# !pip install svgling

# %%
import svgling
svgling.draw_tree(("S", "NP(He)", "VP(ran)"))
# Out:
# TreeLayout(('S', 'NP(He)', 'VP(ran)'))

# %%
import svgling
svgling.draw_tree(("S", "NP(He)", "VP(ran)", "PP(there)"))
# Out:
# TreeLayout(('S', 'NP(He)', 'VP(ran)', 'PP(there)'))

# %%
import svgling
svgling.draw_tree(("S", "NP(He)", ("VP","V(saw)","NP(it)"), "PP(there)"))
# Out:
# TreeLayout(('S', 'NP(He)', ('VP', 'V(saw)', 'NP(it)'), 'PP(there)'))

# %%
import svgling
svgling.draw_tree(("S", ("NP", "Det(the)", "Nom(bear)"), "V(saw)", ("NP","Det(the)","Nom(trout)"), ("PP", "P(in)", "NP(it)")))
# Out:
# TreeLayout(('S', ('NP', 'Det(the)', 'Nom(bear)'), 'V(saw)', ('NP', 'Det(the)', 'Nom(trout)'), ('PP', 'P(in)', 'NP(it)')))

# %%
import svgling
svgling.draw_tree("S",("NP","Det(the)",("Nom","Adj(little)","N(bear)")),("VP",("VP","V(saw)",("NP","Det(the)",("Nom","Adj(fine)","Adj(fat)","N(trout)"))),("PP","P(in)",("NP", "Det(the)", "N(brook)"))))
# Out:
# TreeLayout(('S', ('NP', 'Det(the)', ('Nom', 'Adj(little)', 'N(bear)')), ('VP', ('VP', 'V(saw)', ('NP', 'Det(the)', ('Nom', 'Adj(fine)', 'Adj(fat)', 'N(trout)'))), ('PP', 'P(in)', ('NP', 'Det(the)', 'N(brook)')))))

# %%
#RULE 1 : Rs(Ac,Rn(Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rn (0 or 1)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rn (0 or 1)', 'Ac (Task Event)')))

# %%
#RULE 2 : Rs(Ac,Rn(Ee))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rn (0 or 1)", "Ac (End Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rn (0 or 1)', 'Ac (End Event)')))

# %%
#RULE 3 : Rs(Ac,Rn(Gxs))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rn (0 or 1)", "GXs (Exclusive OR split Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rn (0 or 1)', 'GXs (Exclusive OR split Event)')))

# %%
#RULE 4 : Rs(Ac,Rn(Gxj))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rn (0 or 1)", "GXj (XOR join Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rn (0 or 1)', 'GXj (XOR join Event)')))

# %%
#RULE 5 : Rs(Ac,Rs(Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rs (Sequence)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rs (Sequence)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 6 : Rs(Ac,Rs(Ac,Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rs (Sequence)", "Ac (Task Event)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rs (Sequence)', 'Ac (Task Event)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 7 : Rs(Ac,Rs(Ac,Ee))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rs (Sequence)", "Ac (Task Event)", ("Ee (End Event)"))))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rs (Sequence)', 'Ac (Task Event)', 'Ee (End Event)')))

# %%
#RULE 8 : Rs(Ac, Rs(Ac,Gxs))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rs (Sequence)", "Ac (Task Event)", ("GXs (XOR split Event)"))))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rs (Sequence)', 'Ac (Task Event)', 'GXs (XOR split Event)')))

# %%
#RULE 9 : Rs(Ac, R+(Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("R+ (Parallel Gateway)", "Ac (Task Event)", ("Ac (Task Event)"))))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('R+ (Parallel Gateway)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 10 : Rs(Ac, Rx(Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rx (Exclusive Gateway)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rx (Exclusive Gateway)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 11 : Rs(Ac, Rx(Ac,Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Rx (Exclusive Gateway)", "Ac (Task Event)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Rx (Exclusive Gateway)', 'Ac (Task Event)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 12 : Rs(Ac, Ro(Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ac (Task Event)", ("Ro (Inclusive Gateway)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ac (Task Event)', ('Ro (Inclusive Gateway)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 13 : Rs(Ei, Rn(Ee))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Ei (Intermediate Event)", ("Rn (0 or 1)", "Ee (End Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Ei (Intermediate Event)', ('Rn (0 or 1)', 'Ee (End Event)')))

# %%
#RULE 14 : Rs(Es, Rn(Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Es (Start Event)", ("Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Es (Start Event)', 'Ac (Task Event)'))

# %%
#RULE 15 : Rs(Es, Rs(Ac,Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "Es (Start Event)", ("Rs (Sequence)", "Ac (Task Event)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'Es (Start Event)', ('Rs (Sequence)', 'Ac (Task Event)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 16 : Rs(G+s, Rn(Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "G+s (And split Event)", ("Rn(0 or 1)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'G+s (And split Event)', ('Rn(0 or 1)', 'Ac (Task Event)')))

# %%
#RULE 17 : Rs(G+j, Rn(Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "G+j (And join Event)", ("Rn(0 or 1)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'G+j (And join Event)', ('Rn(0 or 1)', 'Ac (Task Event)')))

# %%
#RULE 18 : Rs(Gxs, Rn(Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rn(0 or 1)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rn(0 or 1)', 'Ac (Task Event)')))

# %%
#RULE 19 : Rs(Gxs, Rn(Ee))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rn(0 or 1)", "Ee (End Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rn(0 or 1)', 'Ee (End Event)')))

# %%
#RULE 20 : Rs(Gxs, Rn(G+s))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rn(0 or 1)", "G+s (And split Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rn(0 or 1)', 'G+s (And split Event)')))

# %%
#RULE 21 : Rs(Gxs, Rn(Gxs))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rn(0 or 1)", "GXs (XOR split Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rn(0 or 1)', 'GXs (XOR split Event)')))

# %%
#RULE 22 : Rs(Gxs,Rs(Ac,Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rs(Sequence)", "Ac (Task Event)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rs(Sequence)', 'Ac (Task Event)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 23 : Rs(Gxs, R+(Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("R+(Parallel Gateway)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('R+(Parallel Gateway)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 24 : Rs(Gxs, Rx(Ac,Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rx(Exclusive Gateway)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rx(Exclusive Gateway)', 'Ac (Task Event)', 'Ac (Task Event)')))

# %%
#RULE 25 : Rs(Gxs, Rx(Ac,Ee))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rx(Exclusive Gateway)", "Ac (Task Event)", "Ee (End Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rx(Exclusive Gateway)', 'Ac (Task Event)', 'Ee (End Event)')))

# %%
#RULE 26 : Rs(Gxs, Rx(Ac, empty))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXs (XOR split Event)", ("Rx(Exclusive Gateway)", "Ac (Task Event)", "empty")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXs (XOR split Event)', ('Rx(Exclusive Gateway)', 'Ac (Task Event)', 'empty')))

# %%
#RULE 27 : Rs(Gxj, Rn(Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXj (XOR join Event)", ("Rn(0 or 1)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXj (XOR join Event)', ('Rn(0 or 1)', 'Ac (Task Event)')))

# %%
#RULE 28 : Rs(Gxj, Rs(Ac, Ee))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXj (XOR join Event)", ("Rs(Sequence)", "Ac (Task Event)", "Ee (End Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXj (XOR join Event)', ('Rs(Sequence)', 'Ac (Task Event)', 'Ee (End Event)')))

# %%
#RULE 29 : Rs(Gxj, R+(Ac, Ac))
import svgling
svgling.draw_tree(("Rs (Sequence)", "GXj (XOR join Event)", ("R+(Parallel Gateway)", "Ac (Task Event)", "Ac (Task Event)")))
# Out:
# TreeLayout(('Rs (Sequence)', 'GXj (XOR join Event)', ('R+(Parallel Gateway)', 'Ac (Task Event)', 'Ac (Task Event)')))
